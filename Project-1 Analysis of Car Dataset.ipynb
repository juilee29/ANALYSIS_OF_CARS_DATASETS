# %% [markdown]
# # Goal: Perform analysis on dataset of different cars with their specifications

# %% [raw]
# 1.Import cars dataset

# %%
import pandas as pd

# %%
A=pd.read_csv('E:/Dataset/Cars93.csv')

# %% [raw]
# 2.Perform Data Profiling

# %%
A.head()
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags      ...       Passengers Length  \
# 0        25           31                 NaN      ...                5    177
# 1        18           25  Driver & Passenger      ...                5    195
# 2        20           26         Driver only      ...                5    180
# 3        19           26  Driver & Passenger      ...                6    193
# 4        22           30         Driver only      ...                4    186
#
# ...

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
# Unnamed: 0            93 non-null int64
# Manufacturer          93 non-null object
# Model                 93 non-null object
# Type                  93 non-null object
# Min.Price             93 non-null float64
# Price                 93 non-null float64
# Max.Price             93 non-null float64
# MPG.city              93 non-null int64
# MPG.highway           93 non-null int64
# AirBags               59 non-null object
# DriveTrain            93 non-null object
# Cylinders             93 non-null object
# EngineSize            93 non-null float64
# Horsepower            93 non-null int64
# RPM                   93 non-null int64
# Rev.per.mile          93 non-null int64
# Man.trans.avail       93 non-null object
# Fuel.tank.capacity    93 non-null float64
# Passengers            93 non-null int64
# Length                93 non-null int64
# ...

# %%
A.describe()
# Out:
#        Unnamed: 0  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# count   93.000000  93.000000  93.000000  93.000000  93.000000    93.000000
# mean    47.000000  17.125806  19.509677  21.898925  22.365591    29.086022
# std     26.990739   8.746029   9.659430  11.030457   5.619812     5.331726
# min      1.000000   6.700000   7.400000   7.900000  15.000000    20.000000
# 25%     24.000000  10.800000  12.200000  14.700000  18.000000    26.000000
# 50%     47.000000  14.700000  17.700000  19.600000  21.000000    28.000000
# 75%     70.000000  20.300000  23.300000  25.300000  25.000000    31.000000
# max     93.000000  45.400000  61.900000  80.000000  46.000000    50.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   93.000000   93.000000    93.000000     93.000000           93.000000
# mean     2.667742  143.827957  5280.645161   2332.204301           16.664516
# ...

# %%
A.shape
# Out:
# (93, 28)

# %% [raw]
# a.Missing Value Treatment

# %%
import matplotlib.pyplot as plt

# %%
A.isnull().sum().plot(kind="barh")#Finding out missing value in dataset in graphical form

# %%
Q = pd.DataFrame(A.isnull().sum(),columns=["missing_vals"])
Q[Q.missing_vals > 0]#Finding out missing value in dataset in column format
# Out:
#                 missing_vals
# AirBags                   34
# Rear.seat.room             2
# Luggage.room              11

# %%
#Separating categorical and continuous columns from the dataset
cat = []
con = []
for i in A.columns:
    if(A[i].dtypes=="object"):
        cat.append(i)
    else:
        con.append(i)

# %%
cat#categorical columns
# Out:
# ['Manufacturer',
#  'Model',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin',
#  'Make']

# %%
con#continuous columns
# Out:
# ['Unnamed: 0',
#  'Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight']

# %%
#Treating missing values of continuous columns
from sklearn.preprocessing import Imputer
imp = Imputer()
C=pd.DataFrame(imp.fit_transform(A[con]),columns=con)

# %%
C
# Out:
#     Unnamed: 0  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 0          1.0       12.9   15.9       18.8      25.0         31.0
# 1          2.0       29.2   33.9       38.7      18.0         25.0
# 2          3.0       25.9   29.1       32.3      20.0         26.0
# 3          4.0       30.8   37.7       44.6      19.0         26.0
# 4          5.0       23.7   30.0       36.2      22.0         30.0
# 5          6.0       14.2   15.7       17.3      22.0         31.0
# 6          7.0       19.9   20.8       21.7      19.0         28.0
# 7          8.0       22.6   23.7       24.9      16.0         25.0
# 8          9.0       26.3   26.3       26.3      19.0         27.0
# 9         10.0       33.0   34.7       36.3      16.0         25.0
# 10        11.0       37.5   40.1       42.7      16.0         25.0
# 11        12.0        8.5   13.4       18.3      25.0         36.0
# 12        13.0       11.4   11.4       11.4      25.0         34.0
# ...

# %%
cat.remove("Manufacturer")
cat.remove("Make")
cat.remove("Model")

# %%
#Treating missing values of categorical columns
from sklearn_pandas import CategoricalImputer
ci = CategoricalImputer()
D=A[cat].apply(ci.fit_transform)

# %%
D
# Out:
#        Type             AirBags DriveTrain Cylinders Man.trans.avail   Origin
# 0     Small         Driver only      Front         4             Yes  non-USA
# 1   Midsize  Driver & Passenger      Front         6             Yes  non-USA
# 2   Compact         Driver only      Front         6             Yes  non-USA
# 3   Midsize  Driver & Passenger      Front         6             Yes  non-USA
# 4   Midsize         Driver only       Rear         4             Yes  non-USA
# 5   Midsize         Driver only      Front         4              No      USA
# 6     Large         Driver only      Front         6              No      USA
# 7     Large         Driver only       Rear         6              No      USA
# 8   Midsize         Driver only      Front         6              No      USA
# 9     Large         Driver only      Front         8              No      USA
# 10  Midsize  Driver & Passenger      Front         8              No      USA
# ...

# %%
E = C.join(D)

# %%
E
# Out:
#     Unnamed: 0  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 0          1.0       12.9   15.9       18.8      25.0         31.0
# 1          2.0       29.2   33.9       38.7      18.0         25.0
# 2          3.0       25.9   29.1       32.3      20.0         26.0
# 3          4.0       30.8   37.7       44.6      19.0         26.0
# 4          5.0       23.7   30.0       36.2      22.0         30.0
# 5          6.0       14.2   15.7       17.3      22.0         31.0
# 6          7.0       19.9   20.8       21.7      19.0         28.0
# 7          8.0       22.6   23.7       24.9      16.0         25.0
# 8          9.0       26.3   26.3       26.3      19.0         27.0
# 9         10.0       33.0   34.7       36.3      16.0         25.0
# 10        11.0       37.5   40.1       42.7      16.0         25.0
# 11        12.0        8.5   13.4       18.3      25.0         36.0
# 12        13.0       11.4   11.4       11.4      25.0         34.0
# ...

# %%
E.shape
# Out:
# (93, 25)

# %%
E.join(A[["Make","Manufacturer","Model"]])
# Out:
#     Unnamed: 0  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 0          1.0       12.9   15.9       18.8      25.0         31.0
# 1          2.0       29.2   33.9       38.7      18.0         25.0
# 2          3.0       25.9   29.1       32.3      20.0         26.0
# 3          4.0       30.8   37.7       44.6      19.0         26.0
# 4          5.0       23.7   30.0       36.2      22.0         30.0
# 5          6.0       14.2   15.7       17.3      22.0         31.0
# 6          7.0       19.9   20.8       21.7      19.0         28.0
# 7          8.0       22.6   23.7       24.9      16.0         25.0
# 8          9.0       26.3   26.3       26.3      19.0         27.0
# 9         10.0       33.0   34.7       36.3      16.0         25.0
# 10        11.0       37.5   40.1       42.7      16.0         25.0
# 11        12.0        8.5   13.4       18.3      25.0         36.0
# 12        13.0       11.4   11.4       11.4      25.0         34.0
# ...

# %%
E=E.drop(labels="Unnamed: 0",axis=1)

# %%
E
# Out:
#     Min.Price  Price  Max.Price  MPG.city  MPG.highway  EngineSize  \
# 0        12.9   15.9       18.8      25.0         31.0         1.8
# 1        29.2   33.9       38.7      18.0         25.0         3.2
# 2        25.9   29.1       32.3      20.0         26.0         2.8
# 3        30.8   37.7       44.6      19.0         26.0         2.8
# 4        23.7   30.0       36.2      22.0         30.0         3.5
# 5        14.2   15.7       17.3      22.0         31.0         2.2
# 6        19.9   20.8       21.7      19.0         28.0         3.8
# 7        22.6   23.7       24.9      16.0         25.0         5.7
# 8        26.3   26.3       26.3      19.0         27.0         3.8
# 9        33.0   34.7       36.3      16.0         25.0         4.9
# 10       37.5   40.1       42.7      16.0         25.0         4.6
# 11        8.5   13.4       18.3      25.0         36.0         2.2
# 12       11.4   11.4       11.4      25.0         34.0         2.2
# ...

# %% [raw]
# 3.Exploratory Data Analysis

# %% [raw]
# a.Univariate Analysis

# %%
list(E.columns)
# Out:
# ['Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin']

# %%
#Separating categorical and continuous columns from dataset
cat = []
con = []
for i in E.columns:
    if(E[i].dtypes=="object"):
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['Type', 'AirBags', 'DriveTrain', 'Cylinders', 'Man.trans.avail', 'Origin']

# %%
con
# Out:
# ['Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight']

# %% [raw]
# Univariate Analysis of continuous columns

# %%
import seaborn as sb
sb.distplot(E.Passengers)

# %% [markdown]
# The above graph represents displot of no. of passengers in each car.The graph gives an idea of passengers accomodate in different cars.

# %%
import matplotlib.pyplot as plt
for i in con:
    sb.distplot(E[i])
    plt.show()

# %% [markdown]
# The above distplot represents spread of data in different continuous columns of dataset.

# %%
import matplotlib.pyplot as plt
for i in con:
    plt.xlabel(i)
    E[i].hist()
    plt.show()

# %% [markdown]
# The above histogram represents frequency of data values in different continuous columns of dataset.

# %% [raw]
# Univariate Analysis of categorical columns

# %%
cat
# Out:
# ['Type', 'AirBags', 'DriveTrain', 'Cylinders', 'Man.trans.avail', 'Origin']

# %%
import matplotlib.pyplot as plt
for i in cat:
    sb.countplot(E[i])
    plt.show()

# %% [markdown]
# The above countplot represents data values in different categorical columns of dataset.

# %%
import matplotlib.pyplot as plt
for i in cat:
    E[i].value_counts().plot(kind="barh")
    plt.show()

# %% [raw]
# The above horizontal bar chart represents data values in different categorical columns of dataset.

# %%
import matplotlib.pyplot as plt
for i in cat:
    E[i].value_counts().plot(kind="pie")
    plt.show()

# %% [raw]
# The above pie chart represents data values in different categorical columns of dataset.

# %% [markdown]
# # Bivariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
E
# Out:
#     Min.Price  Price  Max.Price  MPG.city  MPG.highway  EngineSize  \
# 0        12.9   15.9       18.8      25.0         31.0         1.8
# 1        29.2   33.9       38.7      18.0         25.0         3.2
# 2        25.9   29.1       32.3      20.0         26.0         2.8
# 3        30.8   37.7       44.6      19.0         26.0         2.8
# 4        23.7   30.0       36.2      22.0         30.0         3.5
# 5        14.2   15.7       17.3      22.0         31.0         2.2
# 6        19.9   20.8       21.7      19.0         28.0         3.8
# 7        22.6   23.7       24.9      16.0         25.0         5.7
# 8        26.3   26.3       26.3      19.0         27.0         3.8
# 9        33.0   34.7       36.3      16.0         25.0         4.9
# 10       37.5   40.1       42.7      16.0         25.0         4.6
# 11        8.5   13.4       18.3      25.0         36.0         2.2
# 12       11.4   11.4       11.4      25.0         34.0         2.2
# ...

# %%
#Separating continuous and categorical columns from the dataset
for i in E.columns:
    if(E[i].dtypes == 'object'):
        sb.boxplot(E[i],E.Width)#Boxplot between categorical and continuous columns
        plt.xlabel(i)
        plt.ylabel('Width')
        plt.show()
    else:
        plt.scatter(E[i],E.Width)# Scatter plot between continuous and continuous columns
        plt.xlabel('Width')
        plt.ylabel(i)
        plt.show()

# %%
for i in E.columns:
   if(E[i].dtypes=="object"):
    sb.countplot(E.Origin,hue=E[i])#Countplot with hue between categorical and categorical columns
    plt.ylabel(i)
    plt.show()

# %%
pd.crosstab(E.Origin,E.Type)#Crosstab between categorical and categorical columns
# Out:
# Type     Compact  Large  Midsize  Small  Sporty  Van
# Origin
# USA            7     11       10      7       8    5
# non-USA        9      0       12     14       6    4

# %%
pd.crosstab(E.Origin,E.AirBags)
# Out:
# AirBags  Driver & Passenger  Driver only
# Origin
# USA                       9           39
# non-USA                   7           38

# %%
pd.crosstab(E.Origin,E.DriveTrain)
# Out:
# DriveTrain  4WD  Front  Rear
# Origin
# USA           5     34     9
# non-USA       5     33     7

# %%
pd.crosstab(E.Origin,E.Cylinders)
# Out:
# Cylinders  3   4  5   6  8  rotary
# Origin
# USA        0  22  0  20  6       0
# non-USA    3  27  2  11  1       1

# %%
pd.crosstab(E.Origin,E['Man.trans.avail'])
# Out:
# Man.trans.avail  No  Yes
# Origin
# USA              26   22
# non-USA           6   39

# %% [markdown]
# # Multivariate Analysis

# %%
sb.pairplot(E)#Pair Plots way to visualize relationships between each variable

# %%
E.corr()#Correlation between continuous columns
# Out:
#                     Min.Price     Price  Max.Price  MPG.city  MPG.highway  \
# Min.Price            1.000000  0.970601   0.906756 -0.622875    -0.579966
# Price                0.970601  1.000000   0.981580 -0.594562    -0.560680
# Max.Price            0.906756  0.981580   1.000000 -0.547811    -0.522561
# MPG.city            -0.622875 -0.594562  -0.547811  1.000000     0.943936
# MPG.highway         -0.579966 -0.560680  -0.522561  0.943936     1.000000
# EngineSize           0.645488  0.597425   0.535012 -0.710003    -0.626795
# Horsepower           0.802444  0.788218   0.744445 -0.672636    -0.619044
# RPM                 -0.042598 -0.004955   0.025015  0.363045     0.313469
# Rev.per.mile        -0.470395 -0.426395  -0.374024  0.695857     0.587497
# Fuel.tank.capacity   0.635369  0.619480   0.581294 -0.813144    -0.786039
# Passengers           0.061236  0.057860   0.053216 -0.416856    -0.466386
# Length               0.553859  0.503628   0.442933 -0.666239    -0.542897
# ...

# %%
sb.heatmap(E.corr())#Correlation between continuous columns represented by ploting heat map
